# %%
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("insurance_data.csv")
df.head()
# Out:
#    age  bought_insurance
# 0   22                 0
# 1   25                 0
# 2   47                 1
# 3   52                 0
# 4   46                 1

# %%
plt.xlabel('age(years)')
plt.ylabel('insurance(0/1)')
plt.scatter(df.age,df.bought_insurance)
plt.show()

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(df[['age']],df.bought_insurance,train_size=0.8)

# %%
X_test.head()
# Out:
#     age
# 1    25
# 25   54
# 9    61
# 22   40
# 24   50

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()

# %%
model.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
X_test
# Out:
#     age
# 1    25
# 25   54
# 9    61
# 22   40
# 24   50
# 21   26

# %%
y_predicted = model.predict(X_test)

# %%
model.predict_proba(X_test)
# Out:
# array([[0.8601137 , 0.1398863 ],
#        [0.16881883, 0.83118117],
#        [0.08187146, 0.91812854],
#        [0.51307426, 0.48692574],
#        [0.24533645, 0.75466355],
#        [0.84535697, 0.15464303]])

# %%
model.score(X_test,y_test)
# Out:
# 0.8333333333333334

# %%
y_predicted
# Out:
# array([0, 1, 1, 0, 1, 0])

# %%
y_predicted
# Out:
# array([0, 1, 1, 0, 1, 0])

# %%
model.intercept_
# Out:
# array([-4.75611072])

# %%
model.coef_
# Out:
# array([[0.11759504]])
